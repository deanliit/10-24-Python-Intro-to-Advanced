# %% [markdown]
# #Python Course I - Weekly class demos and Exercises summary
# - (Mon, Wed) - (8am-10:30am) - (2.5h class/demos/labs) / 30 min practice
# - Course II - 10 weeks
#
# #Github Course Notebook Refence
#
# https://github.com/deanliit/10-24-Python-Intro-to-Advanced
#
# #All Weekly Topics
# - function summary
# - import
# - range, slicers, indixes, list comprehension
# - file i/o
# - main startup program
# - Error Handling
# - module import - custom python modules
# - git/github
# - sql database
# - python data analysis - big data - pandas
# - object oriented programming
# - functional programming - lamda
# - html - python screen scraping
# - machine learning using python
# - python example review  - pyhon PCEP, PCAP
# - other
#
# #Current Weekly Topics
# - sql database
# - other
#
# #Weekly Homework , Class Assignment, Class Project
# - reccomended: Reading/review
#   - w3schools reference
#   - pdf ebook ref
#
# - practice labs
#   - google classroom proacice labs
#   - exercises from course book
#
#
# ## Python references
# https://www.w3schools.com/python/python_intro.asp
# - Course book
#
# ### Class Quiz - Email link to google forms
#
# <pre>
# - 3 quizzes - similar to python entry level quiz
# - multiple choice
# - 6 multiple choice quesitons = 85%
# - 1 code fill-in question
# -- write code is vs.code - copy code in quiz
# -- small example program -- %15
# example: write a progarm to compute 2 values
# optional/extra: create a startup program
# input: prompt for each input
# output: display items and total
# hint:
#
# num1 = input("num2")
# num2 = input("num2")
# total = int(num1) + int(num2)
# print("total", total)
#
# - take home
# - approx. 1 week to complete
# - quiz is similar question to python Entry Level Exam. Some question from Associate Exam
# - review quiz in class
#
# </pre>

# %% [markdown]
# <pre>
#
# ---------------------------------------------
# #Course II Module Summary
# -----------------------------------------------
#
# https://www.w3schools.com/python/python_intro.asp
#
# # Module 1
# ---------------------------
# File/IO
# Slicers, Slicing
# List Comprehension
# Main method
# Error Handling
# Module import
# Git/github
# Other
#
# # Module 2
# ----------------------------
# Intro to data analyst using python
# Pandas, numpy
# SQL
#
# # Module 3
# --------------------------------
# Object Oriented Programming, Classes
# Functional Programming
# Lamda
# Other
#
# #Module 4
# ---------------------------------
# HTML - CSS - JavaScript
# Screen scaping, search bots - Beautifulsoup library
# AI/ML - Machine learning
# NLP - Natural Language Processing
#
# #Module 5
# --------------------------------
# Python exam review - pcep, pcap
#
# </pre>

# %%
#demo-read-file-data-1.py

"""

product.csv
------------------------------------------------
item, date, qty, price
tv1, 5/1/21, 5, 112.32
tv2, 1/5/21, 10, 312.42

...............

f = open("product.csv")

for item in f:
  print(item)

f.close()

...........................
"""

item = "item, date, qty, price"
row = item.strip().split(",")

print(row)
print(row[0])
# Out:
# ['item', ' date', ' qty', ' price']
# item

# %%
#pandas-demo-1.py

#pandas library - read and extract data from text files (csv, excel) etc..
#pandas create in-memory table called dataframe
#not reccomended to strire millions of rows from a file
#reccomende to use with small to mid size data

#https://www.programiz.com/python-programming/pandas/getting-started

#pip install pandas

import pandas as pd

# read csv file and create a dataframe
#df = pd.read_csv('product3.csv', header = 0)
df = pd.read_csv('product3.csv')

print(df)
# Out:
#         item       date   qty   price
# 0        tv1     5/1/21     5  112.32
# 1        tv2     1/5/21    10  312.42
# 2   sneaker1    1/20/22     1   89.36
# 3   sneaker2    12/5/23    20  238.23
# 4      book1    8/10/23     1   73.20
# 5      book2   11/10/24    15   52.36
# 6    laptop1     4/8/23     5  324.00
# 7    laptop2    7/18/22     1  522.57
# 8    tablet1    1/28/20    30   67.37
# 9    tablet2     7/8/21     2   78.32
# 10    watch1    6/19/23    20  234.38
# 11    watch2    4/27/21     4   83.28

# %%
#pandas-demo-2.py
import pandas as pd

# read csv file and create a dataframe
#df = pd.read_csv('product3.csv', header = 0)
df = pd.read_csv('product3.csv')

#datafrme
#print(df)

#all features of similar to sql
#filter, add, update, delete, other

#display top 5 items
print(df.head())

print()

#display last 5 items
print(df.tail())

print()

#filter by columns
#cols = ['item',' qty'] #add space in column array

df[["item"," date"]]
# Out:
#        item      date   qty   price
# 0       tv1    5/1/21     5  112.32
# 1       tv2    1/5/21    10  312.42
# 2  sneaker1   1/20/22     1   89.36
# 3  sneaker2   12/5/23    20  238.23
# 4     book1   8/10/23     1   73.20
#
#        item      date   qty   price
# 7   laptop2   7/18/22     1  522.57
# 8   tablet1   1/28/20    30   67.37
# 9   tablet2    7/8/21     2   78.32
# 10   watch1   6/19/23    20  234.38
# 11   watch2   4/27/21     4   83.28
#         item       date
# 0        tv1     5/1/21
# 1        tv2     1/5/21
# 2   sneaker1    1/20/22
# 3   sneaker2    12/5/23
# 4      book1    8/10/23
# 5      book2   11/10/24
# 6    laptop1     4/8/23
# 7    laptop2    7/18/22
# 8    tablet1    1/28/20
# 9    tablet2     7/8/21
# 10    watch1    6/19/23
# 11    watch2    4/27/21

# %% [markdown]
# #Introduction to pandas, numpy and data analysis
# - https://www.programiz.com/python-programming/pandas/getting-started
#
# ## retieving various information about data
# ## also asking quesrions about data
# ## create graphs and charts
#
#
# ## pandas sql comparison
# -  https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_sql.html
