# %% [markdown]
# #Python Course I - Weekly class demos and Exercises summary
# - (Mon, Wed) - (8am-10:30am) - (2.5h class/demos/labs) / 30 min practice
# - Course II - 10 weeks
#
# #Github Course Notebook Refence
#
# https://github.com/deanliit/10-24-Python-Intro-to-Advanced
#
# #All Weekly Topics
# - function summary
# - import
# - range, slicers, indixes, list comprehension
# - file i/o
# - main startup program
# - Error Handling
# - module import - custom python modules
# - git/github
# - sql database
# - python data analysis - big data - pandas
# - object oriented programming
# - functional programming - lamda
# - html - python screen scraping
# - machine learning using python
# - python example review  - pyhon PCEP, PCAP
# - other
#
# #Current Weekly Topics
# - sql database
# - other
#
# #Weekly Homework , Class Assignment, Class Project
# - reccomended: Reading/review
#   - w3schools reference
#   - pdf ebook ref
#
# - practice labs
#   - google classroom proacice labs
#   - exercises from course book
#
#
# ## Python references
# https://www.w3schools.com/python/python_intro.asp
# - Course book
#
# ### Class Quiz - Email link to google forms
#
# <pre>
# - 3 quizzes - similar to python entry level quiz
# - multiple choice
# - 6 multiple choice quesitons = 85%
# - 1 code fill-in question
# -- write code is vs.code - copy code in quiz
# -- small example program -- %15
# example: write a progarm to compute 2 values
# optional/extra: create a startup program
# input: prompt for each input
# output: display items and total
# hint:
#
# num1 = input("num2")
# num2 = input("num2")
# total = int(num1) + int(num2)
# print("total", total)
#
# - take home
# - approx. 1 week to complete
# - quiz is similar question to python Entry Level Exam. Some question from Associate Exam
# - review quiz in class
#
# </pre>

# %% [markdown]
# <pre>
#
# ---------------------------------------------
# #Course II Module Summary
# -----------------------------------------------
#
# https://www.w3schools.com/python/python_intro.asp
#
# # Module 1
# ---------------------------
# File/IO
# Slicers, Slicing
# List Comprehension
# Main method
# Error Handling
# Module import
# Git/github
# Other
#
# # Module 2
# ----------------------------
# Intro to data analyst using python
# Pandas, numpy
# SQL
#
# # Module 3
# --------------------------------
# Object Oriented Programming, Classes
# Functional Programming
# Lamda
# Other
#
# #Module 4
# ---------------------------------
# HTML - CSS - JavaScript
# Screen scaping, search bots - Beautifulsoup library
# AI/ML - Machine learning
# NLP - Natural Language Processing
#
# #Module 5
# --------------------------------
# Python exam review - pcep, pcap
#
# </pre>

# %%
"""

Write a program to save data from the following content to a text file.
Compute the total of content when reading the content of text file.
Display the computed total.

102
7.9
302.0
139.3
536
27.5
230.10

write a function to save text file content
write a function to read text file content
Compute the total of content when reading the content of text file
Display computed total
include try except statement

"""

items = [102,7.9,302.0,139.3,536,27.5,230.10]

def write_invoice_data(item):
  #save each item
  #write item on a new line

def read_invoice_data():
  total = 0.0
  #read data file
  f = open("invoice-1.txt")
  #Compute the total of content when reading the content of text file

  return total

def main():
  write_invoice_data("102")
  write_invoice_data("7.9")

  #-or-
  for item in items:
    write_invoice_data(item)

# %% [markdown]
# ## Introduction to SQL
#
# https://www.w3schools.com/sql/
#
# Database = file containing structured data ie: table/schema, rows, columns
#
# SQL is a standard language for storing, manipulating and retrieving data in databases. SQL - universal/common language/code used to manipulate or retrieve data from a database.
#
# Our SQL tutorial will teach you how to use SQL in: MySQL, SQL Server, MS Access, Oracle, Sybase, Informix, Postgres, and other database systems.
#
# SQLite = portable text based full featured database
#
# <pre>
# RDBMS - Relational Transactional database
#       - Realtime , transactional systems
#
# NO-SQL/Json text documents
#
# Databases:
#
# on-Premise:
# - Oracle, Sql Server, Other
#
# Hybrid SQl and NO-SQL/Json text documents:
# - MySql
# - Postgresql
#
# Cloud:
# - Aws RDS
# - Azure: Sql Server
# - Gcp -
#
# portable:
# - Microsoft Access
# - Sqlite
#
# #Sqlite - full featured local text base database
#
# https://sqlitebrowser.org/dl/
#
# DB Browser for SQLite - Standard installer for 64-bit Windows
#
# also: MacOs, Liinux
#
# </pre>

# %%
#sql introduction
