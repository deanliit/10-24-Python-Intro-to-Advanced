# %% [markdown]
# #Python Course I - Weekly class demos and Exercises summary
# - (Mon, Wed) - (8am-10:30am) - (2.5h class/demos/labs) / 30 min practice
# - Course I - 7 weeks
# - Course II - 10 weeks
#
# #Github Course Notebook Refence
#
# https://github.com/deanliit/10-24-Python-Intro-to-Advanced
#
# #Weekly Topics
#  - intro to google colab,
#  - vs.code extensions
#  - array/list/collections,set,map/dict,tuple, loop, crud- create, update, delete, lookup
# - range, slicers, list comprehension
# - functions, file i/o
# - import, date
# - other
#
# #Weekly Homework , Class Assignment, Class Project
# - reccomended: Reading/review
#   - w3schools reference
#   - https://www.w3schools.com/python/
#     - comment, varibles, data types, casting, input, array, loop
#   - pdf ebook ref
#
# - practice labs
#  - create intro python code using google colabs
#    - ie: print, markdown text
#
# - exercises , course book pages
# - pages:
#    -
#
# ## Python references
# https://www.w3schools.com/python/python_intro.asp
# - Course book
#
# ### Class Quiz - Email link to google forms
#
# <pre>
# - 3 quizzes - similar to python entry level quiz
# - multiple choice
# - 6 multiple choice quesitons = 85%
# - 1 code fill-in question
# -- write code is vs.code - copy code in quiz
# -- small example program -- %15
# example: write a progarm to compute 2 values
# optional/extra: create a startup program
# input: prompt for each input
# output: display items and total
# hint:
#
# num1 = input("num2")
# num2 = input("num2")
# total = int(num1) + int(num2)
# print("total", total)
#
# - take home
# - approx. 1 week to complete
# - quiz is similar question to python Entry Level Exam. Some question from Associate Exam
# - review quiz in class
#
# </pre>

# %% [markdown]
# <pre>
#
# ---------------------------------------------
# #Course I Module Summary
# -----------------------------------------------
#
# https://www.w3schools.com/python/python_intro.asp
#
# # Module 1
# ---------------------------
# Python fundamentals
# Data type
# Variables
# Input
# for, while loop
# Other
#
# # Module 2
# ----------------------------
# Array index
# Slicers, list comprehension
# Functions
# File input
# Other
#
# # Module 3
# --------------------------------
# Data structures
# Array, set, list, tuple, map
# Classes
# Lamda
# Other
#
# #optional - Module 4
# ---------------------------------
# Intro to data analyst using python
# Pandas, numpy
# SQL
# Other
#
# </pre>

# %%
#collection, python code statemens, code block summary

"""

array/list = [1,2,3,3] #can contain duplicate
tuple = (1,2,3,3) #read-only
set = {1,2,3} # non  duplicate
dict = {k1:1,k2:2,item3:3} #key , non duplicate

len - length of collection
index , begin:0, end len-1
CRUD - create, update, delete
retieve items via index
looking if item exits in collection

python code statement, ends with a colan:
  indentation

-------------------------------------------

for var in collection:
  code block
  code block

"""

# %%
#-------- instorduction to tuple  ------------
#--- 1. looping, 2. indexing/slicing/range, 3. crud - create, update, delete, 4. lookup items ----
#--------------------------------------------

#--- 1. looping
#--- 2. indexing
#--- 3. crud - create, update, delete
#--- 4. lookup items

# %%
#week6-tuple-demo-1.py
#
#-------- instorduction to tuple (read-only) ------------
#--- 1. looping, 2. indexing/slicing/range, 3. crud - create, update, delete, 4. lookup items ----
#--------------------------------------------

#--- 1. looping

inv_items = (1.5,2,3.1,4,5,5,6.2,7,8.1,8.1,9,10.2)

total = 0.0

#functional programming
#total = sum(inv_items)

#list comprehension
#[print(item) for item in inv_items]

#while loop

"""
for i in range(len(inv_items)):
  total = total + inv_items[i]
"""

for item in inv_items:
  #total = total + item
  total += item #short hand computation (x = x + 1) or (x += 1)

#print("total: ", total)
print("total: ", round(total,2))

# %%
#week6-tuple-demo-2.py
#
#-------- instorduction to tuple (read-only) ------------
#--- 1. looping, 2. indexing/slicing/range, 3. crud - create, update, delete, 4. lookup items ----
#--------------------------------------------

#--- 2. indexing/slicing/range

inv_items = (1.5,2,3.1,4,5,5,6.2,7,8.1,8.1,9,10.2)

total = 0.0

print(inv_items)
print()

#indexing  - set, dict - n/a
print("index  1:",inv_items[1])
print("index -1:",inv_items[-1])
print("index  3:",inv_items[3])
print("index -3:",inv_items[-3])

#---range/slicers/slicing --- set, dict - n/a
#-stop 1 less than the end number ie: stop at 5 = stop at (5-1) = 4
print("slice_array 1:5: ",inv_items[1:5])
print("slice_array 0:10:2: ",inv_items[0:10:2])
print("slice_array -5:-1: ",inv_items[-5:-1])
print("slice_array -5:-1:-1: ",inv_items[-5:-1:-1])
print("slice_array -5:-1:-2: ",inv_items[-5:-1:2])
print("slice_array -5:-1:-3: ",inv_items[-5:-1:3])

# %%
#week6-tuple-demo-3.py
"""
CRUD operations - create/insert, update, delete
retieve items via index
looking if item exits in collection
"""

#--- tuple - read only  ---
inv_items = (1.5,2,3.1,4,5,5,6.2,7,8.1,8.1,9,10.2)

print(inv_items)

"""
updating tuple best practices:
1- create aliost from a tuple then update list, then convert list to tuple
2- slice a top and creata new tuple from slice

example-1:
tuple_list = list(inv_items)
updated_tuple tuple(tuple_list)

example-2:
new_tuple1 = inv_items[1:5] + inv_items[-5:-1]
new_tuple2 = tuple(inv_items[1:5],inv_items[-5:-1])

"""

#array/list-add  - tuple - n/a
#inv_items.append(3.5)

#array/list-update - tuple - n/a, set - n/a
#inv_items[2] = 7.2

#array/list-delete - tuple - n/a
#del inv_items[3]
#inv_items.pop(7) #delete at index 7
#inv_items.remove(5) #delete first value 5 from array
#inv_items.clear() #delete all items

#---- array/list/tuple/set/map-lookup
if 10.2 in inv_items:
    print("10.2 exist in inv_items")
else:
    print("10.2 does NOT exist in inv_items")

# %%
#-------- instorduction to set  ------------
#--- 1. looping, 2. indexing/slicing/range, 3. crud - create, update, delete, 4. lookup items ----
#--------------------------------------------

#--- 1. looping
#--- 2. indexing
#--- 3. crud - create, update, delete
#--- 4. lookup items

# %%
#week6-set-demo-1.py

#-------- instorduction to set (do not allow duplicates) ------------
#--- 1. looping, 2. indexing/slicing/range, 3. crud - create, update, delete, 4. lookup items ----
#--------------------------------------------

#--- 1. looping - set - does not allow duplicates

#inv_items = set(1.5,2,3.1,4,5,5,6.2,7,8.1,8.1,9,10.2)
inv_items = {1.5,2,3.1,4,5,5,6.2,7,8.1,8.1,9,10.2}

total = 0.0

#functional programming
sum_total = sum(inv_items)
print("sum_total: ", sum_total)

#list comprehension
#[print(item) for item in inv_items]

#while loop

"""
for i in range(len(inv_items)):
  total = total + inv_items[i] - index - set/dict - n/a
"""


print()
print(inv_items)
print("len: ", len(inv_items))
print()

i=0

for item in inv_items:
  #custom code - compute index and slicers
  i += 1
  print(i,": ", item)

print()
print("--- for loop/compute total --- ")
print()

for item in inv_items:
  #total = total + item
  total += item #short hand computation (x = x + 1) or (x += 1)

#print("total: ", total)
print("total: ", round(total,2))
# Out:
# sum_total:  56.099999999999994
#
# {1.5, 2, 3.1, 4, 5, 6.2, 7, 8.1, 9, 10.2}
# len:  10
#
# 1 :  1.5
# 2 :  2
# 3 :  3.1
# 4 :  4
# 5 :  5
# 6 :  6.2
# 7 :  7
# 8 :  8.1
# 9 :  9
# 10 :  10.2
#
# --- for loop/compute total ---
#
# total:  56.1

# %%
#week6-set-demo-2.py
#

#--- 2. indexing/slicing/range

# does not allow duplicates
inv_items = {1.5,2,3.1,4,5,5,6.2,7,8.1,8.1,9,10.2}

print(inv_items)
print("len: ", len(inv_items))
print()

#indexing  - set, dict - n/a
#print("index  1:",inv_items[1])
#print("index -1:",inv_items[-1])
#print("index  3:",inv_items[3])
#print("index -3:",inv_items[-3])

#---range/slicers/slicing --- set, dict - n/a
#-stop 1 less than the end number ie: stop at 5 = stop at (5-1) = 4
#print("slice_array 1:5: ",inv_items[1:5])
#print("slice_array 0:10:2: ",inv_items[0:10:2])
#print("slice_array -5:-1: ",inv_items[-5:-1])
#print("slice_array -5:-1:-1: ",inv_items[-5:-1:-1])
#print("slice_array -5:-1:-2: ",inv_items[-5:-1:2])
#print("slice_array -5:-1:-3: ",inv_items[-5:-1:3])

i=0

#or while loop
for item in inv_items:
  #inv_item[i] = n/a - set, dict
  #custom code - compute index and slicers
  i += 1
  print((i-1),": inv_items[", (i-1) ,"]: ", item)
# Out:
# {1.5, 2, 3.1, 4, 5, 6.2, 7, 8.1, 9, 10.2}
# len:  10
#
# 0 : inv_items[ 0 ]:  1.5
# 1 : inv_items[ 1 ]:  2
# 2 : inv_items[ 2 ]:  3.1
# 3 : inv_items[ 3 ]:  4
# 4 : inv_items[ 4 ]:  5
# 5 : inv_items[ 5 ]:  6.2
# 6 : inv_items[ 6 ]:  7
# 7 : inv_items[ 7 ]:  8.1
# 8 : inv_items[ 8 ]:  9
# 9 : inv_items[ 9 ]:  10.2

# %%
#week6-set-demo-3.py

"""
CRUD operations - create/insert, update, delete
retieve items via index - n/a
looking if item exits in collection
"""

#-- set - does not contain duplicates  ---
#-- keys insteads of values
inv_items = {1.5,2,3.1,4,5,5,6.2,7,8.1,8.1,9,10.2}

print(inv_items)
print("len: ", len(inv_items))

#set-add  - ie: key
inv_items.add(3.5)


print()
print(inv_items)
print("len: ",len(inv_items))
print()

#array/list-update - n/a, set - n/a
#inv_items[2] = 7.2

#array/list-delete -
#del inv_items[3] - n/a
inv_items.remove(5) #delete first value 5 from array

#if item does not exist, python generates an error - KeyError
#inv_items.remove(11.4) #delete first value 5 from array

#inv_items.clear() #delete all items

print()
print(inv_items)
print("len: ",len(inv_items))
print()

#---- array/list/tuple/set/map-lookup
if 10.2 in inv_items:
    print("10.2 exist in inv_items")
else:
    print("10.2 does NOT exist in inv_items")
# Out:
# {1.5, 2, 3.1, 4, 5, 6.2, 7, 8.1, 9, 10.2}
# len:  10
#
# {1.5, 2, 3.1, 4, 5, 6.2, 7, 8.1, 9, 10.2, 3.5}
# len:  11
#
#
# {1.5, 2, 3.1, 4, 6.2, 7, 8.1, 9, 10.2, 3.5}
# len:  10
#
# 10.2 exist in inv_items

# %%
##
## dictiony ie: Map - stores, key/value pairs
##
## NO-SQL syntax - key/value pair - use in unstructured data - or text document data
## Json Document Syntax - key/value pair - Javascript object notation - ie: NO-SQL
## nested dictionaries
## parsing nested dictionaries/Json NO-SQL Documents
##

#-------- instorduction to dictionary / map - key/value ------------
#--- 1. looping, 2. indexing/slicing/range, 3. crud - create, update, delete, 4. lookup items ----
#--------------------------------------------

#--- 1. looping
#--- 2. indexing
#--- 3. crud - create, update, delete
#--- 4. lookup items

# %%
#week6-set-demo-1.py

#-------- instorduction to set (do not allow duplicates) ------------
#--- 1. looping, 2. indexing/slicing/range, 3. crud - create, update, delete, 4. lookup items ----
#--------------------------------------------

#--- 1. looping - dict - does not allow duplicates key

#dict = key:value - key=any avalid data type , vlaue = any valid data type
#dict = does not allow duplicate keys
inv_items1 = {1.5:"a1",2:"b1",3.1:"a1",4:"c1",5:"d1",5:"e1",6.2:"a1",7:"f1",8.1:"g1",8.1:"h1",9:"i1",10.2:"j1"}
inv_items2 = {"a1":1.5,
 "b1":2,
 "b2":3.1,
 "c1":4,
 "c1":5,
 "c2":5,
 "d1":6.2,
 "e1":7,
 "f1":8.1,
 "f1":8.1,
 "g1":9,
 "h1":10.2}

#inv_items = dict({"a1":1.5,"b1":2,"b2":3.1,"c1":4,"c1":5,"c2":5,"d1":6.2,"e1":7,"f1":8.1,"f1":8.1,"g1":9,"h1":10.2})
inv_items = {"a1":1.5,"b1":2,"b2":3.1,"c1":4,"c1":5,"c2":5,"d1":6.2,"e1":7,"f1":8.1,"f1":8.1,"g1":9,"h1":10.2}

total = 0.0

#functional programming
#sum_total = sum(inv_items)
#print("sum_total: ", sum_total)

#list comprehension
#[print(item) for item in inv_items]

#while loop

"""
for i in range(len(inv_items)):
  total = total + inv_items[i] - index - set/dict - n/a
"""

print()
print(inv_items)
print("len: ", len(inv_items))
print()

i=0

for item in inv_items:
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ", item)

print()
print("--- for loop/key --- ")
print()

i=0

for item in inv_items.keys():
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ", item)

print()
print("--- for loop/values --- ")
print()

i=0

for item in inv_items.values():
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ", item)

print()
print("--- for loop/items - key:value --- ")
print()

i=0

for key,value in inv_items.items():
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ", key, ":", value)

print()
print("--- for loop/[key-index]  --- ")
print()

i=0

for key in inv_items:
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ","inv_item[", key,"]", inv_items[key])

print()
print("--- for loop/compute total --- ")
print()

#for item in inv_items:
  #total = total + item
  #total += item #short hand computation (x = x + 1) or (x += 1)

#print("total: ", total)
#print("total: ", round(total,2))
# Out:
# {'a1': 1.5, 'b1': 2, 'b2': 3.1, 'c1': 5, 'c2': 5, 'd1': 6.2, 'e1': 7, 'f1': 8.1, 'g1': 9, 'h1': 10.2}
# len:  10
#
# 0 :  a1
# 1 :  b1
# 2 :  b2
# 3 :  c1
# 4 :  c2
# 5 :  d1
# 6 :  e1
# 7 :  f1
# 8 :  g1
# 9 :  h1
#
# --- for loop/key ---
#
# 0 :  a1
# 1 :  b1
# 2 :  b2
# 3 :  c1
# 4 :  c2
# 5 :  d1
# 6 :  e1
# 7 :  f1
# 8 :  g1
# 9 :  h1
#
# --- for loop/values ---
#
# 0 :  1.5
# 1 :  2
# 2 :  3.1
# 3 :  5
# 4 :  5
# 5 :  6.2
# 6 :  7
# 7 :  8.1
# 8 :  9
# 9 :  10.2
#
# --- for loop/items - key:value ---
#
# 0 :  a1 : 1.5
# 1 :  b1 : 2
# 2 :  b2 : 3.1
# 3 :  c1 : 5
# 4 :  c2 : 5
# 5 :  d1 : 6.2
# 6 :  e1 : 7
# 7 :  f1 : 8.1
# 8 :  g1 : 9
# 9 :  h1 : 10.2
#
# --- for loop/[key-index]  ---
#
# 0 :  inv_item[ a1 ] 1.5
# 1 :  inv_item[ b1 ] 2
# 2 :  inv_item[ b2 ] 3.1
# 3 :  inv_item[ c1 ] 5
# 4 :  inv_item[ c2 ] 5
# 5 :  inv_item[ d1 ] 6.2
# 6 :  inv_item[ e1 ] 7
# 7 :  inv_item[ f1 ] 8.1
# 8 :  inv_item[ g1 ] 9
# 9 :  inv_item[ h1 ] 10.2
#
# --- for loop/compute total ---
