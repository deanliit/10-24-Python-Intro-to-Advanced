# %% [markdown]
# #Python Course I - Weekly class demos and Exercises summary
# - (Mon, Wed) - (8am-10:30am) - (2.5h class/demos/labs) / 30 min practice
# - Course I - 7 weeks
# - Course II - 10 weeks
#
# #Github Course Notebook Refence
#
# https://github.com/deanliit/10-24-Python-Intro-to-Advanced
#
# #Weekly Topics
#  - intro to google colab,
#  - vs.code extensions
#  - dictionary , key/value, non duplicate, looping, indexing, crud - create, update, delete, lookup
# - functions, return, parameters, default parameters
# - import, date
# - range, slicers, list comprehension
# - min, max
# - file i/o
# - other
#
# #Weekly Homework , Class Assignment, Class Project
# - reccomended: Reading/review
#   - w3schools reference
#   - https://www.w3schools.com/python/
#     - comment, varibles, data types, casting, input, array, loop
#   - pdf ebook ref
#
# - practice labs
#  - create intro python code using google colabs
#    - ie: print, markdown text
#
# - exercises , course book pages
# - pages:
#    -
#
# ## Python references
# https://www.w3schools.com/python/python_intro.asp
# - Course book
#
# ### Class Quiz - Email link to google forms
#
# <pre>
# - 3 quizzes - similar to python entry level quiz
# - multiple choice
# - 6 multiple choice quesitons = 85%
# - 1 code fill-in question
# -- write code is vs.code - copy code in quiz
# -- small example program -- %15
# example: write a progarm to compute 2 values
# optional/extra: create a startup program
# input: prompt for each input
# output: display items and total
# hint:
#
# num1 = input("num2")
# num2 = input("num2")
# total = int(num1) + int(num2)
# print("total", total)
#
# - take home
# - approx. 1 week to complete
# - quiz is similar question to python Entry Level Exam. Some question from Associate Exam
# - review quiz in class
#
# </pre>

# %% [markdown]
# <pre>
#
# ---------------------------------------------
# #Course I Module Summary
# -----------------------------------------------
#
# https://www.w3schools.com/python/python_intro.asp
#
# # Module 1
# ---------------------------
# Python fundamentals
# Data type
# Variables
# Input
# for, while loop
# Other
#
# # Module 2
# ----------------------------
# Array index
# Slicers, list comprehension
# Functions
# File input
# Other
#
# # Module 3
# --------------------------------
# Data structures
# Array, set, list, tuple, map
# Classes
# Lamda
# Other
#
# #optional - Module 4
# ---------------------------------
# Intro to data analyst using python
# Pandas, numpy
# SQL
# Other
#
# </pre>

# %%
##
## dictiony ie: Map - stores, key/value pairs
##
## NO-SQL syntax - key/value pair - use in unstructured data - or text document data
## Json Document Syntax - key/value pair - Javascript object notation - ie: NO-SQL
## nested dictionaries
## parsing nested dictionaries/Json NO-SQL Documents
##

#-------- instorduction to dictionary / map - key/value ------------
#--- 1. looping, 2. indexing/slicing/range, 3. crud - create, update, delete, 4. lookup items ----
#--------------------------------------------

#--- 1. looping
#--- 2. indexing
#--- 3. crud - create, update, delete
#--- 4. lookup items

# %%
#week7-dict-demo-1.py

#-------- instorduction to set (do not allow duplicates) ------------
#--- 1. looping, 2. indexing/slicing/range, 3. crud - create, update, delete, 4. lookup items ----
#--------------------------------------------

#--- 1. looping - dict - does not allow duplicates key

#dict = key:value - key=any avalid data type , vlaue = any valid data type
#dict = does not allow duplicate keys
inv_items1 = {1.5:"a1",2:"b1",3.1:"a1",4:"c1",5:"d1",5:"e1",6.2:"a1",7:"f1",8.1:"g1",8.1:"h1",9:"i1",10.2:"j1"}
inv_items2 = {"a1":1.5,
 "b1":2,
 "b2":3.1,
 "c1":4,
 "c1":5,
 "c2":5,
 "d1":6.2,
 "e1":7,
 "f1":8.1,
 "f1":8.1,
 "g1":9,
 "h1":10.2}

#inv_items = dict({"a1":1.5,"b1":2,"b2":3.1,"c1":4,"c1":5,"c2":5,"d1":6.2,"e1":7,"f1":8.1,"f1":8.1,"g1":9,"h1":10.2})
inv_items = {"a1":1.5,"b1":2,"b2":3.1,"c1":4,"c1":5,"c2":5,"d1":6.2,"e1":7,"f1":8.1,"f1":8.1,"g1":9,"h1":10.2}

total = 0.0

#functional programming
#sum_total = sum(inv_items)
#print("sum_total: ", sum_total)

#list comprehension
#[print(item) for item in inv_items]

#while loop

"""
for i in range(len(inv_items)):
  total = total + inv_items[i] - index - set/dict - n/a
"""

print()
print(inv_items)
print("len: ", len(inv_items))
print()

i=0

for item in inv_items:
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ", item)

print()
print("--- for loop/key --- ")
print()

i=0

for item in inv_items.keys():
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ", item)

print()
print("--- for loop/values --- ")
print()

i=0

for item in inv_items.values():
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ", item)

print()
print("--- for loop/items - key:value --- ")
print()

i=0

for key,value in inv_items.items():
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ", key, ":", value)

print()
print("--- for loop/[key-index]  --- ")
print()

i=0

for key in inv_items:
  #custom code - compute index and slicers
  i += 1
  print((i-1),": ","inv_item[", key,"]", inv_items[key])

print()
print("--- for loop/compute total --- ")
print()

#for item in inv_items:
  #total = total + item
  #total += item #short hand computation (x = x + 1) or (x += 1)

#print("total: ", total)
#print("total: ", round(total,2))

# %%
#week2-dict-demo-2.py
#

#--- 2. indexing/slicing/range

# does not allow duplicates, has key: value pair
#inv_items = dict({"a1":1.5,"b1":2,"b2":3.1,"c1":4,"c1":5,"c2":5,"d1":6.2,"e1":7,"f1":8.1,"f1":8.1,"g1":9,"h1":10.2})
inv_items = {"a1":1.5,"b1":2,"b2":3.1,"c1":4,"c1":5,"c2":5,"d1":6.2,"e1":7,"f1":8.1,"f1":8.1,"g1":9,"h1":10.2}

print(inv_items)
print("len: ", len(inv_items))
print()

#indexing  - set, dict - n/a
#print("index  1:",inv_items[1])
#print("index -1:",inv_items[-1])
#print("index  3:",inv_items[3])
#print("index -3:",inv_items[-3])

#---range/slicers/slicing --- set, dict - n/a
#-stop 1 less than the end number ie: stop at 5 = stop at (5-1) = 4
#print("slice_array 1:5: ",inv_items[1:5])
#print("slice_array 0:10:2: ",inv_items[0:10:2])
#print("slice_array -5:-1: ",inv_items[-5:-1])
#print("slice_array -5:-1:-1: ",inv_items[-5:-1:-1])
#print("slice_array -5:-1:-2: ",inv_items[-5:-1:2])
#print("slice_array -5:-1:-3: ",inv_items[-5:-1:3])

i=0

#or while loop
for k,v in inv_items.items():
  #inv_item[i] = n/a - set, dict
  #custom code - compute index and slicers
  i += 1
  print((i-1),": inv_items[", (i-1) ," : ", k ,"]: ", v)

print()
print("inv_items['b1']: ",inv_items["b1"])
#print("inv_items['b3']: ",inv_items["b3"]) #//KeyError on lookup if key does not exists
# Out:
# {'a1': 1.5, 'b1': 2, 'b2': 3.1, 'c1': 5, 'c2': 5, 'd1': 6.2, 'e1': 7, 'f1': 8.1, 'g1': 9, 'h1': 10.2}
# len:  10
#
# 0 : inv_items[ 0  :  a1 ]:  1.5
# 1 : inv_items[ 1  :  b1 ]:  2
# 2 : inv_items[ 2  :  b2 ]:  3.1
# 3 : inv_items[ 3  :  c1 ]:  5
# 4 : inv_items[ 4  :  c2 ]:  5
# 5 : inv_items[ 5  :  d1 ]:  6.2
# 6 : inv_items[ 6  :  e1 ]:  7
# 7 : inv_items[ 7  :  f1 ]:  8.1
# 8 : inv_items[ 8  :  g1 ]:  9
# 9 : inv_items[ 9  :  h1 ]:  10.2
#
# inv_items['b1']:  2

# %%
#week7-dict-demo-3.py


"""
CRUD operations - create/insert, update, delete
retieve items via index - n/a
looking if item exits in collection
"""

# does not allow duplicates, has key: value pair
#inv_items = dict({"a1":1.5,"b1":2,"b2":3.1,"c1":4,"c1":5,"c2":5,"d1":6.2,"e1":7,"f1":8.1,"f1":8.1,"g1":9,"h1":10.2})
inv_items = {"a1":1.5,"b1":2,"b2":3.1,"c1":4,"c1":5,"c2":5,"d1":6.2,"e1":7,"f1":8.1,"f1":8.1,"g1":9,"h1":10.2}

print(inv_items)
print("len: ", len(inv_items))

#dict-add/update  - ie: key
inv_items["a2"]=3.5 #add ke/value if not exists, update key/value if exists
inv_items.update({"a3":183.5}) #add ke/value if not exists, update key/value if exists

print()
print(inv_items)
print("len: ",len(inv_items))
print()

#dict-update - set - n/a
inv_items.update({"a3":19.5}) #add ke/value if not exists, update key/value if exists

#array/list-delete -
#del inv_items[3] - n/a
inv_items.pop("a3") #delete item via key

#if item does not exist, python generates an error - KeyError
#inv_items.pop("a5") #if key does not exists KeyError

#inv_items.clear() #delete all items

print()
print(inv_items)
print("len: ",len(inv_items))
print()

#---- array/list/tuple/set/map-lookup
#if 10.2 in inv_items:
#if 10.2 in inv_items.keys():
if 10.2 in inv_items.values():
    print("10.2 exist in inv_items")
else:
    print("10.2 does NOT exist in inv_items")
# Out:
# {'a1': 1.5, 'b1': 2, 'b2': 3.1, 'c1': 5, 'c2': 5, 'd1': 6.2, 'e1': 7, 'f1': 8.1, 'g1': 9, 'h1': 10.2}
# len:  10
#
# {'a1': 1.5, 'b1': 2, 'b2': 3.1, 'c1': 5, 'c2': 5, 'd1': 6.2, 'e1': 7, 'f1': 8.1, 'g1': 9, 'h1': 10.2, 'a2': 3.5, 'a3': 183.5}
# len:  12
#
#
# {'a1': 1.5, 'b1': 2, 'b2': 3.1, 'c1': 5, 'c2': 5, 'd1': 6.2, 'e1': 7, 'f1': 8.1, 'g1': 9, 'h1': 10.2, 'a2': 3.5}
# len:  11
#
# 10.2 exist in inv_items

# %%
##
## dictiony ie: Map - stores, key/value pairs
##
## NO-SQL syntax - key/value pair - use in unstructured data - or text document data
## Json Document Syntax - key/value pair - Javascript object notation - ie: NO-SQL
## nested dictionaries
## parsing nested dictionaries/Json NO-SQL Documents
##

#python dict = same as Json document, NO-SQL
#
#data structure is nested dict or JSON document, NO-SQL - unstructured data
#ie: MongoDb - No-SQL database
#

inv_items = {"a1":1,"b1":2,"c1":{
    "itema":[1,2,3],
    "itemb":(1,2,4),
    "itemc": {"a1":1,"b2":2}
}}

#same loop except nested dict
#nested loop : for for or [list comprehension]

#same update except nested dict
#inv_items["a1"]["itema"]

# %%
"""
functions, return, parameters, default parameters
import, date
range, slicers, list comprehension
min, max
file i/o
other
"""

# %%
#functions-demo-1.py
#functions, return, parameters, default parameters
#https://www.w3schools.com/python/python_functions.asp
"""
functions:
giving a group of code statement/code blocks a name
as you write more larger application you can optimizae code into functions
- mainly used to refactor repeated code, simplify/reduct large code blocks
- for code re-use
- example: if code block is > 20 lines of code
- fucntions
- can have input parameters
- can have default parameters
- return data
"""

def funct1():
  print("code statment") #no input parameter
  #any valid pyhton code

def funct2(param1):
  print("code statment: ", param1)  #parameter can be any valid data type
  #any valid pyhton code

def funct3(param1, param2):
  print("code statment: ", param1, param2) #parameter can be any valid data type
  #any valid pyhton code

def funct4(param1, param2, param3):
  print("code statment: ", param1, param2, param3) #parameter can be any valid data type
  #any valid pyhton code
  return (param1 + param2 + param3)

#call a fucntions
funct1()
funct2(1)
funct3(2,3)
total = funct4(4,5,6)
print("total: ", total)
# Out:
# code statment
# code statment:  1
# code statment:  2 3
# code statment:  4 5 6
# total:  15

# %%
#functions-demo-2".py
#functions, return, parameters, default parameters
#https://www.w3schools.com/python/python_functions.asp

#default parameters
def functa(param1="a"):
  print("code statment", param1) #no input parameter
  #any valid pyhton code

functa()
functa("")
functa(None)
functa("1")
# Out:
# code statment a
# code statment
# code statment None
# code statment 1
